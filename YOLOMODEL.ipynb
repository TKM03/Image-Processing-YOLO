# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics

# %%
# dataset_path = 'train/images'

# %%
  # from ultralytics import YOLO

  # # Load the YOLOv8 model
  # model = YOLO('yolov8n.pt')  # You can use 'yolov8s.pt', 'yolov8m.pt', etc.

  # # Train the model using 10% sampled data
  # model.train(data='/content/drive/MyDrive/Pothole detection YOLOv8.v1i.yolov8/data.yaml', epochs=15, imgsz=640, patience=5 )
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 24.9MB/s]
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# # Validate the model
# model.val()
# Out:
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Pothole detection YOLOv8.v1i.yolov8/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:38<00:00,  5.49s/it]
#                    all        100        436      0.659       0.44       0.53      0.215
# Speed: 5.5ms preprocess, 348.9ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to runs/detect/train2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7abb5c216890>
# ...

# %%
# results = model.predict(source='/content/drive/MyDrive/Pothole detection YOLOv8.v1i.yolov8/testimage.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Pothole detection YOLOv8.v1i.yolov8/testimage.jpg: 384x640 (no detections), 133.5ms
# Speed: 3.2ms preprocess, 133.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train3

# %% [markdown]
# ## Start Here

# %%
# Save the trained model as a .pt file for future use
from ultralytics import YOLO
import cv2

model_path = 'trained_yolov8_model.pt'
model = YOLO(model_path)

# %%
# Path to the image you want to test
image_path = 'test5.jpg'

# Run the prediction
results = model.predict(source=image_path, save=False)

# Load the original image using OpenCV
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Could not load the image.")
else:
    # Loop over results and draw the bounding boxes
    for result in results:
        for box in result.boxes:
            # Extract the bounding box coordinates
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Convert to integer
            conf = box.conf.item()  # Get confidence score
            class_id = box.cls.item()  # Get class index

            # Draw the bounding box on the image
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Add a label with the class and confidence score
            label = f'{result.names[class_id]}: {conf:.2f}'
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the image with bounding boxes using OpenCV
    cv2.imshow('YOLOv8 Test Result', image)
    cv2.waitKey(0)  # Wait for a key press
    cv2.destroyAllWindows()  # Close the OpenCV window
# Out:
# image 1/1 C:\Users\chewr\Downloads\Pothole detection YOLOv8.v1i.yolov8\test5.jpg: 448x640 1 Potholes, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Save the image with bounding boxes to a file
output_image_path = 'output_test_result.jpg'
cv2.imwrite(output_image_path, image)
print(f"Output saved to {output_image_path}")
# Out:
# Output saved to output_test_result.jpg

# %%
# Path to your trained YOLOv8 model
model_path = 'trained_yolov8_model.pt'

# Load the YOLOv8 model
model = YOLO(model_path)

# Open the webcam (0 is the default camera; you can change the index for external cameras)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open the webcam.")
    exit()

while True:
    # Capture frame-by-frame from the webcam
    ret, frame = cap.read()

    if not ret:
        print("Failed to grab frame.")
        break

    # Run the YOLO model on the captured frame
    results = model.predict(source=frame, save=False)

    # Loop over results and draw bounding boxes
    for result in results:
        for box in result.boxes:
            # Extract the bounding box coordinates
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Convert to integer
            conf = box.conf.item()  # Get confidence score
            class_id = box.cls.item()  # Get class index

            # Draw the bounding box on the frame
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Add a label with the class and confidence score
            label = f'{result.names[class_id]}: {conf:.2f}'
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the frame with bounding boxes in a window
    cv2.imshow('YOLOv8 Real-Time Detection', frame)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 97.4ms
# Speed: 6.4ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.3ms
# Speed: 2.4ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.6ms
# Speed: 0.8ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.5ms
# Speed: 1.8ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 4.9ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.8ms
# Speed: 2.4ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
